# %% [markdown]
# # Python Einführung
#
# Heute wollen wir **Python** lernen!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# Dies ist ein Kommentar
print("Hallo zusammen")
# Out:
# Hallo zusammen

# %% [markdown]
# # Einfache Datentypen

# %%
# Variable und Wertezuweisung
name = "Lovelace"
print(name)
# Out:
# Lovelace

# %%
# String - Zeichenkette
first_name = "Ada"
print(first_name)
# Out:
# Ada

# %%
# Integer - Ganzzahl
age = 37
print(age)
# Out:
# 37

# %%
# Float - Gleitkommazahl
size = 1.7123
print(size)
# Out:
# 1.7123

# %%
# Boolean - Boolsche Werte
knows_math = True
likes_gardening = False

# %%
# Typen anzeigen lassen
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# ## Operatoren

# %%
# Addition
5+5
# Out:
# 10

# %%
# Multiplikation
age * 100
# Out:
# 3700

# %%
# Verkettung von Strings
name + name
# Out:
# 'LovelaceLovelace'

# %%
# Multiplikation von Strings
name * 10
# Out:
# 'LovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelaceLovelace'

# %%
# Vermischung von Datentypen
name + str(10)
# Out:
# 'Lovelace10'

# %% [markdown]
# # Funktionen und Methoden

# %%
len(name)
# Out:
# 8

# %%
# Methode
name.upper()
# Out:
# 'LOVELACE'

# %%
name.count("E")
# Out:
# 0

# %%
name = name.upper()
name.count("E")
# Out:
# 2

# %%
name.replace("LACE", " is everywhere")
# Out:
# 'LOVE is everywhere'

# %% [markdown]
# # Listen und Dictionaries

# %%
# Liste
list_names = ["Lovelace", "Darwin", "Noether", "Hawkins"]
list_names
# Out:
# ['Lovelace', 'Darwin', 'Noether', 'Hawkins']

# %%
list_names[-1]
list_names[0:3]
# Out:
# ['Lovelace', 'Darwin', 'Noether']

# %%
# Dictionary
dict_names = {"Lovelace": 1815, 
              "Darwin": 1809, 
              "Noether": 1882, 
              "Hawking":1942}

# %%
dict_names["Darwin"]
# Out:
# 1809

# %%
dict_names.keys()
# Out:
# dict_keys(['Lovelace', 'Darwin', 'Noether', 'Hawking'])

# %%
dict_names.values()
# Out:
# dict_values([1815, 1809, 1882, 1942])

# %%
for person in list_names: print(person)
# Out:
# Lovelace
# Darwin
# Noether
# Hawkins

# %% [markdown]
# # Bedingte Anweisungen (Conditionals)

# %%
temp = 20

if temp > 15:
    print("It's warm")
# Out:
# It's warm

# %%
temp = 15
if temp >= 25:
    print("It's hot")
elif temp >= 15:
    print("It's warm")
else: 
    print("It's cold")
# Out:
# It's warm
